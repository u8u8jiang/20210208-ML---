# %%
import urllib.request as req
url="https://www.kkday.com/zh-tw/product/ajax_productlist/?country=&city=&keyword=%E5%8F%B0%E5%8D%97%E5%B8%82&availstartdate=&availenddate=&cat=TAG_4_4&time=&glang=&sort=rdesc&page=1&row=10&fprice=*&eprice=*&precurrency=TWD&csrf_token_name=d840df7741e3cb9df1302c3b8231afeb"
request=req.Request(url, headers={ "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36 Edg/86.0.622.68"
})
with req.urlopen(request) as response:
    data=response.read().decode("utf-8") 
print(data)
# Out:
# {"status":"success","msg":"","total":21,"page":1,"total_page":3,"page_title":"\u53f0\u5357\u5e02\u7cbe\u9078\u5546\u54c1 - KKday","data":[{"id":21814,"prod_oid":21814,"name":"\u53f0\u5357\u6a5f\u8eca\u79df\u8eca | \u53f0\u5357\u53e4\u5df7\u901f\u5ba2\u9054","introduction":"\u7acb\u5373\u9810\u8a02\u53f0\u5357\u706b\u8eca\u7ad9\u524d\u6a5f\u8eca\u79df\u501f\uff0c\u4f86\u8d9f\u53f0\u5357\u6700\u5728\u5730\u7684\u73a9\u6cd5\uff0c\u524d\u5f80\u5b89\u5e73\u666f\u9ede\u54c1\u5690\u7f8e\u98df\u3001\u89c0\u5915\u5e73\u53f0\uff0c\u5230\u82b1\u5712\u591c\u5e02\u4ea4\u901a\u8f15\u9b06\u641e\u5b9a\u3002","rating_count":38,"rating_star":4.76,"order_count":170,"confirm_hour":5,"instant_booking":false,"instant_use":false,"free_refund_policy":true,"free_refund_before_day":8,"earliest_sale_date":"20210217","sale_status":"1","purchase_type":null,"purchase_date":null,"is_tourism_product":false,"readable_url":null,"main_cat_key":"M04","promo_tag_keys":[],"cat_key":["TAG_5_3","TAG_4_4"],"theme_code":["554","555"],"product_labels":[],"img_url":"https:\/\/image.kkday.com\/v2\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20201028022305_edLqf\/jpg","img_url_list":["https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20201028022305_edLqf\/jpg","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20190227070655_Q2xOd\/jpg","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20201015062655_NtbCp\/jpg","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20190227071459_fUcPo\/png","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20201015062627_CfCdW\/jpg","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20201015071115_eNlFi\/jpg","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_21814\/20201028022304_foY1F\/jpg"],"duration":0,"days":0,"hours":0,"minutes":0,"currency":"TWD","display_sale_price":"200","sale_price":200,"display_price":"200","price":200,"is_display_price":false,"app_cheaper_than_web":false,"countries":[{"id":"A01-001","name":"\u53f0\u7063","cities":[{"id":"A01-001-00003","name":"\u53f0\u5357"}]}],"cities":[{"id":"A01-001-00003","name":"\u53f0\u5357"}],"star_percentage":["100","100","100","100",75],"show_url_order_num":"100+","country_key":["A01-001"],"city_key":["A01-001-00003"],"show_city_name":"\u53f0\u5357","show_country_name":"\u53f0\u7063","show_order_count":"100+","show_rating_star":["100","100","100","100",75],"url":"https:\/\/www.kkday.com\/zh-tw\/product\/21814"},{"id":2953,"prod_oid":2953,"name":"\u53f0\u7063\u53f0\u5357\uff5c\u4e00\u65e5\u5305\u8eca\uff5c\u8d64\u5d01\u6a13\uff06\u6797\u767e\u8ca8\uff06\u82b1\u5712\u591c\u5e02","introduction":"\u73fe\u5728\u9810\u7d04\u53f0\u5357\u5305\u8eca\u65c5\u904a\u5e36\u4f60\u4e00\u5929\u4e4b\u5167\u8d70\u8a2a\u53f0\u5357\u8d64\u5d01\u6a13\u3001\u6797\u767e\u8ca8\u3001\u82b1\u5712\u591c\u5e02\uff01\u53f0\u5357\u3001\u9ad8\u96c4\u5e02\u5340\u7686\u53ef\u63a5\u9001\uff0c\u5f48\u6027\u6c7a\u5b9a\u81ea\u5df1\u7684\u53f0\u5357\u65c5\u904a\uff0c\u8d70\u904d\u71b1\u9580\u53f0\u5357\u666f\u9ede\u8d85\u65b9\u4fbf\uff01","rating_count":76,"rating_star":4.63,"order_count":311,"confirm_hour":48,"instant_booking":false,"instant_use":false,"free_refund_policy":true,"free_refund_before_day":8,"earliest_sale_date":"20210212","sale_status":"1","purchase_type":null,"purchase_date":null,"is_tourism_product":true,"readable_url":null,"main_cat_key":"M04","promo_tag_keys":[],"cat_key":["TAG_4_4","TAG_4_6","TAG_4_1"],"theme_code":[],"product_labels":[],"img_url":"https:\/\/image.kkday.com\/v2\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_2953\/20150826083155_F76rX\/jpg","img_url_list":["https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_2953\/20150826083155_F76rX\/jpg","https:\/\/image.kkday.com\/image\/get\/w_600%2Cc_fit\/s1.kkday.com\/product_2953\/2015072 ...

# %%
import json 
data=json.loads(data)
print(data)
# Out:
# {'status': 'success', 'msg': '', 'total': 21, 'page': 1, 'total_page': 3, 'page_title': '台南市精選商品 - KKday', 'data': [{'id': 21814, 'prod_oid': 21814, 'name': '台南機車租車 | 台南古巷速客達', 'introduction': '立即預訂台南火車站前機車租借，來趟台南最在地的玩法，前往安平景點品嚐美食、觀夕平台，到花園夜市交通輕鬆搞定。', 'rating_count': 38, 'rating_star': 4.76, 'order_count': 170, 'confirm_hour': 5, 'instant_booking': False, 'instant_use': False, 'free_refund_policy': True, 'free_refund_before_day': 8, 'earliest_sale_date': '20210217', 'sale_status': '1', 'purchase_type': None, 'purchase_date': None, 'is_tourism_product': False, 'readable_url': None, 'main_cat_key': 'M04', 'promo_tag_keys': [], 'cat_key': ['TAG_5_3', 'TAG_4_4'], 'theme_code': ['554', '555'], 'product_labels': [], 'img_url': 'https://image.kkday.com/v2/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20201028022305_edLqf/jpg', 'img_url_list': ['https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20201028022305_edLqf/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20190227070655_Q2xOd/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20201015062655_NtbCp/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20190227071459_fUcPo/png', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20201015062627_CfCdW/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20201015071115_eNlFi/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_21814/20201028022304_foY1F/jpg'], 'duration': 0, 'days': 0, 'hours': 0, 'minutes': 0, 'currency': 'TWD', 'display_sale_price': '200', 'sale_price': 200, 'display_price': '200', 'price': 200, 'is_display_price': False, 'app_cheaper_than_web': False, 'countries': [{'id': 'A01-001', 'name': '台灣', 'cities': [{'id': 'A01-001-00003', 'name': '台南'}]}], 'cities': [{'id': 'A01-001-00003', 'name': '台南'}], 'star_percentage': ['100', '100', '100', '100', 75], 'show_url_order_num': '100+', 'country_key': ['A01-001'], 'city_key': ['A01-001-00003'], 'show_city_name': '台南', 'show_country_name': '台灣', 'show_order_count': '100+', 'show_rating_star': ['100', '100', '100', '100', 75], 'url': 'https://www.kkday.com/zh-tw/product/21814'}, {'id': 2953, 'prod_oid': 2953, 'name': '台灣台南｜一日包車｜赤崁樓＆林百貨＆花園夜市', 'introduction': '現在預約台南包車旅遊帶你一天之內走訪台南赤崁樓、林百貨、花園夜市！台南、高雄市區皆可接送，彈性決定自己的台南旅遊，走遍熱門台南景點超方便！', 'rating_count': 76, 'rating_star': 4.63, 'order_count': 311, 'confirm_hour': 48, 'instant_booking': False, 'instant_use': False, 'free_refund_policy': True, 'free_refund_before_day': 8, 'earliest_sale_date': '20210212', 'sale_status': '1', 'purchase_type': None, 'purchase_date': None, 'is_tourism_product': True, 'readable_url': None, 'main_cat_key': 'M04', 'promo_tag_keys': [], 'cat_key': ['TAG_4_4', 'TAG_4_6', 'TAG_4_1'], 'theme_code': [], 'product_labels': [], 'img_url': 'https://image.kkday.com/v2/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150826083155_F76rX/jpg', 'img_url_list': ['https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150826083155_F76rX/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150728065328_6dgZL/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20161212090709_cuZut/png', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150728065134_vdgvB/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150728065838_E2v2J/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150728054047_bSMGL/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150728100118_XynZs/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20150728071035_kx0e3/jpg', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.com/product_2953/20161212090711_5VdFr/png', 'https://image.kkday.com/image/get/w_600%2Cc_fit/s1.kkday.co ...

# %%
posts=data["data"]
print("票券名稱:")
for key in posts:
    title = key["name"]
    print(title)
# Out:
# 票券名稱:
# 台南機車租車 | 台南古巷速客達
# 台灣台南｜一日包車｜赤崁樓＆林百貨＆花園夜市
# 南台灣一日包車｜台南、高雄、墾丁自選｜高雄出發
# 台灣台南包車｜跟著孤味遊台南｜電影經典場景一日遊
# 【熱門景點包車一日遊】高雄雙溪樹木園、美濃客家文物、台南烏山頭水庫（高雄出發、台南結束）
# 【深度旅遊】台南古都＆烏山頭一日遊｜高雄＆台南出發
# 台南溫泉一日遊｜ 關子嶺溫泉 & 台江國家公園 & 玻璃天空步道 ｜ 台南市區彈性接送
# 兒童軍事體驗｜樂酷童萌｜小兵日記&小小波麗士體驗營
# 台南文化景點接送 | 鹿耳門聖母廟．四草綠色隧道．安平樹屋．夕遊出張所．藍晒圖文創園區 | 高雄出發
# 台灣一日遊行程｜路線輕鬆任選｜台北出發（兩人同行一人免費！）

# %%
print("票券詳細內容連結:")
for key in posts:
    title = key["url"]
    print(title)
# Out:
# 票券詳細內容連結:
# https://www.kkday.com/zh-tw/product/21814
# https://www.kkday.com/zh-tw/product/2953
# https://www.kkday.com/zh-tw/product/20111
# https://www.kkday.com/zh-tw/product/113875
# https://www.kkday.com/zh-tw/product/27612
# https://www.kkday.com/zh-tw/product/277
# https://www.kkday.com/zh-tw/product/104648
# https://www.kkday.com/zh-tw/product/114102
# https://www.kkday.com/zh-tw/product/114154
# https://www.kkday.com/zh-tw/product/101500

# %%
print("票券價格:")
for key in posts:
    title = key["price"]
    print(title)
# Out:
# 票券價格:
# 200
# 3800
# 1000
# 4000
# 5778
# 1200
# 1200
# 735
# 715
# 1399

# %%
print("最早可使用日期:")
for key in posts:
    title = key["earliest_sale_date"]
    print(title)
# Out:
# 最早可使用日期:
# 20210217
# 20210212
# 20210217
# 20210217
# 20210217
# 20210215
# 20210217
# 20210301
# 20210218
# 20210217

# %%
print("評價:")
for key in posts:
    title = key["rating_star"]
    print(title)
# Out:
# 評價:
# 4.76
# 4.63
# 4.49
# 0
# 0
# 4.42
# 4.33
# 5
# 5
# 4
