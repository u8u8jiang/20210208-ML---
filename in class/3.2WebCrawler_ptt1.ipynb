# %%
#抓取PTT省錢版網頁的原始碼
import urllib.request as request 
# src="https://www.ptt.cc/bbs/Lifeismoney/index.html"
src = "https://www.ptt.cc/bbs/EAseries/index.html"
with request.urlopen(src) as response:
    data=response.read().decode("utf-8")
print(data)  #HTTPError: HTTP Error 403: Forbidden

# %%
#抓取PTT省錢版網頁的原始碼
import urllib.request as request 
#src="https://www.ptt.cc/bbs/Lifeismoney/index.html"
src = "https://www.ptt.cc/bbs/EAseries/index.html"
requestUA=request.Request(src, headers={
   # "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36 Edg/86.0.622.68"
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36"
})   #你是誰？User-Agent，確認是否為正常瀏覽，給request才抓得到
with request.urlopen(requestUA) as response:
    data=response.read().decode("utf-8")
print(data)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 EAseries 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/EAseries/index.html"><span class="board-label">看板 </span>EAseries</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/EAseries/index.html">看板</a>
# 				<a class="btn" href="/man/EAseries/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/EAseries/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/EAseries/index2317.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/EAseries/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/EAseries/M.1612689804.A.469.html">[請益] Netflix未提供觀看（黑帆）</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">gn046187</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs
>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">chopper0424</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E8%99%9B%E6%93%AC%E6%9C%8D%E5%8B%99%E7%BD%AE%E5%BA%95%E5%8D%80&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/EAseries/search?q=author%3Achopper0424">搜尋看板內 chopper0424 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/07</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">41</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/EAseries/M.1482764862.A.5D6.html">[公告] 置底閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">chopper0424</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E5%8D%80">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/EAseries/search?q=author%3Achopper0424">搜尋看板內 chopper0424 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">12/26</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
import bs4
root=bs4.BeautifulSoup(data, "html.parser") #讓BeautifulSoup協助解析HTML格式文件
print(root)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 EAseries 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/EAseries/index.html"><span class="board-label">看板 </span>EAseries</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/EAseries/index.html">看板</a>
# <a class="btn" href="/man/EAseries/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/EAseries/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/EAseries/index2317.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/EAseries/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">5</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612689804.A.469.html">[請益] Netflix未提供觀看（黑帆）</a>
# </div>
# <div class="meta">
# <div class="author">gn046187</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+Netflix%E6%9C%AA%E6%8F%90%E4%BE%9B%E8%A7%80%E7%9C%8B%EF%BC%88%E9%BB%91%E5%B8%86%EF%BC%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Agn046187">搜尋看板內 gn046187 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612694381.A.73B.html">[心得] Legacies S03E03 (雷)</a>
# </div>
# <div class="meta">
# <div class="author">allmoon</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%BF%83%E5%BE%97%5D+Legacies+S03E03+%28%E9%9B%B7%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Aallmoon">搜尋看板內 allmoon 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612712632.A.382.html">[心得] 飆風不歸路 第三季</a>
# </div>
# <div class="meta">
# <div class="author">ELclaire</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%BF%83%E5%BE%97%5D+%E9%A3%86%E9%A2%A8%E4%B8%8D%E6%AD%B8%E8%B7%AF+%E7%AC%AC%E4%B8%89%E5%AD%A3">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3AELclaire">搜尋看板內 ELclaire 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">33</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612743906.A.907.html">[新聞] 獵鷹與酷寒戰士超級盃預告</a>
# </div>
# <div class="meta">
# <div class="author">chingswn</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%B5%E9%B7%B9%E8%88%87%E9%85%B7%E5%AF%92%E6%88%B0%E5%A3%AB%E8%B6%85%E7%B4%9A%E7%9B%83%E9%A0%90%E5%91%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Achingswn">搜尋看板內 chingswn 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">23</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612749334.A.458.html">[請益] 求推薦經典劇</a>
# </div>
# <div class="meta">
# <div class="author">dodobaho</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+%E6%B1%82%E6%8E%A8%E8%96%A6%E7%B6%93%E5%85%B8%E5%8A%87">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Adodobaho">搜尋看板內 dodobaho 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">36</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612758241.A.D42.html">[閒聊] 美國消防員收入很高嗎(9-1-1)</a>
# </div>
# <div class="meta">
# <div class="author">Frobel</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+%E7%BE%8E%E5%9C%8B%E6%B6%88%E9%98%B2%E5%93%A1%E6%94%B6%E5%85%A5%E5%BE%88%E9%AB%98%E5%97%8E%289-1-1%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3AFrobel">搜尋看板內 Frobel 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
#
# 				(本文已被刪除) [RedGrandfa]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612764836.A.4ED.html">[商品] 賣LOST一到六季</a>
# </div>
# <div class="meta">
# <div class="author">RedGrandfa</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%95%86%E5%93%81%5D+%E8%B3%A3LOST%E4%B8%80%E5%88%B0%E5%85%AD%E5%AD%A3">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3ARedGrandfa">搜尋看板內 RedGrandfa 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612768343.A.BDC.html">[新聞] NF《三人要守密，兩人得死去》首曝預告</a>
# </div>
# <div class="meta">
# <div class="author">CYKONGG</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+NF%E3%80%8A%E4%B8%89%E4%BA%BA%E8%A6%81%E5%AE%88%E5%AF%86%EF%BC%8C%E5%85%A9%E4%BA%BA%E5%BE%97%E6%AD%BB%E5%8E%BB%E3%80%8B%E9%A6%96%E6%9B%9D%E9%A0%90%E5%91%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3ACYKONGG">搜尋看板內 CYKONGG 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">17</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612771339.A.206.html">[新聞] 《后翼棄兵》不推第二季！安雅有不同想法</a>
# </div>
# <div class="meta">
# <div class="author">CYKONGG</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E3%80%8A%E5%90%8E%E7%BF%BC%E6%A3%84%E5%85%B5%E3%80%8B%E4%B8%8D%E6%8E%A8%E7%AC%AC%E4%BA%8C%E5%AD%A3%EF%BC%81%E5%AE%89%E9%9B%85%E6%9C%89%E4%B8%8D%E5%90%8C%E6%83%B3%E6%B3%95">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3ACYKONGG">搜尋看板內 CYKONGG 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612789939.A.D98.html">[請益] 絕命律師第五季Lalo的鞋子哪裡有賣??</a>
# </div>
# <div class="meta">
# <div class="author">krokopaja</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+%E7%B5%95%E5%91%BD%E5%BE%8B%E5%B8%AB%E7%AC%AC%E4%BA%94%E5%AD%A3Lalo%E7%9A%84%E9%9E%8B%E5%AD%90%E5%93%AA%E8%A3%A1%E6%9C%89%E8%B3%A3%3F%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Akrokopaja">搜尋看板內 krokopaja 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612797727.A.DE9.html">[討論] Netflix 韓國首部太空科幻片-勝利號</a>
# </div>
# <div class="meta">
# <div class="author">wsp0323</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+Netflix+%E9%9F%93%E5%9C%8B%E9%A6%96%E9%83%A8%E5%A4%AA%E7%A9%BA%E7%A7%91%E5%B9%BB%E7%89%87-%E5%8B%9D%E5%88%A9%E8%99%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Awsp0323">搜尋看板內 wsp0323 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612801690.A.D23.html">[心得] Your Honor E09 (雷)</a>
# </div>
# <div class="meta">
# <div class="author">ariachiang</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%BF%83%E5%BE%97%5D+Your+Honor+E09+%28%E9%9B%B7%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Aariachiang">搜尋看板內 ariachiang 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612829756.A.977.html">[心得] Netflix 螳螂 S1 無雷 小推 </a>
# </div>
# <div class="meta">
# <div class="author">UncleJenny</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%BF%83%E5%BE%97%5D+Netflix+%E8%9E%B3%E8%9E%82+S1+%E7%84%A1%E9%9B%B7+%E5%B0%8F%E6%8E%A8+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3AUncleJenny">搜尋看板內 UncleJenny 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612832913.A.120.html">[收視] 眼鏡蛇道館 KO 柏捷頓非NF僅有靈魂急轉彎</a>
# </div>
# <div class="meta">
# <div class="author">ariachiang</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E6%94%B6%E8%A6%96%5D+%E7%9C%BC%E9%8F%A1%E8%9B%87%E9%81%93%E9%A4%A8+KO+%E6%9F%8F%E6%8D%B7%E9%A0%93%E9%9D%9ENF%E5%83%85%E6%9C%89%E9%9D%88%E9%AD%82%E6%80%A5%E8%BD%89%E5%BD%8E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Aariachiang">搜尋看板內 ariachiang 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1612848387.A.72B.html">[新聞] 為遺珠抱憾！《艾》編劇入圍反批評審太白</a>
# </div>
# <div class="meta">
# <div class="author">CYKONGG</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%82%BA%E9%81%BA%E7%8F%A0%E6%8A%B1%E6%86%BE%EF%BC%81%E3%80%8A%E8%89%BE%E3%80%8B%E7%B7%A8%E5%8A%87%E5%85%A5%E5%9C%8D%E5%8F%8D%E6%89%B9%E8%A9%95%E5%AF%A9%E5%A4%AA%E7%99%BD">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3ACYKONGG">搜尋看板內 CYKONGG 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/G.1312986065.A.1C1.html">[公告] 新手常見問題集</a>
# </div>
# <div class="meta">
# <div class="author">ChanelN5</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%96%B0%E6%89%8B%E5%B8%B8%E8%A6%8B%E5%95%8F%E9%A1%8C%E9%9B%86">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3AChanelN5">搜尋看板內 ChanelN5 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/10</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1585892934.A.6E2.html">[公告] 板規I新聞相關規範 </a>
# </div>
# <div class="meta">
# <div class="author">chopper0424</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8FI%E6%96%B0%E8%81%9E%E7%9B%B8%E9%97%9C%E8%A6%8F%E7%AF%84+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Achopper0424">搜尋看板內 chopper0424 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/03</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1585893697.A.12A.html">[公告] 歐美影集板規 3.1 </a>
# </div>
# <div class="meta">
# <div class="author">chopper0424</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%AD%90%E7%BE%8E%E5%BD%B1%E9%9B%86%E6%9D%BF%E8%A6%8F+3.1+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Achopper0424">搜尋看板內 chopper0424 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/03</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1491546319.A.331.html">[公告] 虛擬服務置底區 </a>
# </div>
# <div class="meta">
# <div class="author">chopper0424</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E8%99%9B%E6%93%AC%E6%9C%8D%E5%8B%99%E7%BD%AE%E5%BA%95%E5%8D%80+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Achopper0424">搜尋看板內 chopper0424 的文章</a></div>
# </div>
# </div>
# <div class="date"> 4/07</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">41</span></div>
# <div class="title">
# <a href="/bbs/EAseries/M.1482764862.A.5D6.html">[公告] 置底閒聊區</a>
# </div>
# <div class="meta">
# <div class="author">chopper0424</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/EAseries/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E5%8D%80">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/EAseries/search?q=author%3Achopper0424">搜尋看板內 chopper0424 的文章</a></div>
# </div>
# </div>
# <div class="date">12/26</div>
# <div class="mark">M</div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
print(root.title)#尋找"title"標籤
# Out:
# <title>看板 EAseries 文章列表 - 批踢踢實業坊</title>

# %%
print(root.title.string)#尋找"title"標籤字串
# Out:
# 看板 EAseries 文章列表 - 批踢踢實業坊

# %%
titles=root.find("div", class_="title") #尋找class="title"的div標籤
print(titles)
# Out:
# <div class="title">
# <a href="/bbs/EAseries/M.1612689804.A.469.html">[請益] Netflix未提供觀看（黑帆）</a>
# </div>

# %%
print(titles.div)

# %%
# print(titles.div.string) #裡面都是標籤，是空的
print(root.title.string)

# %%
titles=root.find_all("div", class_="title") #尋找所有class="title"的div標籤
print(titles)

# %%
count=0
for title in titles:
    print(count, title)
    count=count+1

# %%
for title in titles:
    if title.a != None: #如果標題包含a標籤 (沒有被刪除), 印出來
        print(title.a.string)

# %%
import urllib.request as request 
import bs4

def GetTitle(src):
    requestUA = request.Request(src, headers={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36"
    })   
    with request.urlopen(requestUA) as response:
        data=response.read().decode("utf-8")
        pass
    root = bs4.BeautifulSoup(data, "html.parser")
    titles = root.find_all("div", class_="title") #尋找所有class="title"的div標籤
 
    for title in titles:
        if title.a != None: #如果標題包含a標籤 (沒有被刪除), 印出來
            print(title.a.string)
            pass
        pass
    pass

GetTitle('https://www.ptt.cc/bbs/EAseries/index.html')
# Out:
# [請益] Netflix未提供觀看（黑帆）
# [心得] Legacies S03E03 (雷)
# [心得] 飆風不歸路 第三季
# [新聞] 獵鷹與酷寒戰士超級盃預告
# [請益] 求推薦經典劇
# [閒聊] 美國消防員收入很高嗎(9-1-1)
# [商品] 賣LOST一到六季
# [新聞] NF《三人要守密，兩人得死去》首曝預告
# [新聞] 《后翼棄兵》不推第二季！安雅有不同想法
# [請益] 絕命律師第五季Lalo的鞋子哪裡有賣??
# [討論] Netflix 韓國首部太空科幻片-勝利號
# [心得] Your Honor E09 (雷)
# [心得] Netflix 螳螂 S1 無雷 小推
# [收視] 眼鏡蛇道館 KO 柏捷頓非NF僅有靈魂急轉彎
# [新聞] 為遺珠抱憾！《艾》編劇入圍反批評審太白
# [公告] 新手常見問題集
# [公告] 板規I新聞相關規範
# [公告] 歐美影集板規 3.1
# [公告] 虛擬服務置底區
# [公告] 置底閒聊區

# %%
# get the header in ppt

import urllib.request as request 
import bs4

def GetTitle(name):
    src = 'https://www.ptt.cc/bbs/'+name+'/index.html'
    requestUA = request.Request(src, headers={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36"
    })   
    with request.urlopen(requestUA) as response:
        data=response.read().decode("utf-8")
        pass
    root = bs4.BeautifulSoup(data, "html.parser")
    titles = root.find_all("div", class_="title") #尋找所有class="title"的div標籤
 
    for title in titles:
        if title.a != None: #如果標題包含a標籤 (沒有被刪除), 印出來
            print(title.a.string)
            pass
        pass
    pass

GetTitle('Stock')
